# %%
# Standard Python behavior
def play_game(score: int):
    print(f"Your score is {score}!")

# We said 'score' is an integer, but we give it a string.
# Python doesn't care, it just runs it anyway!
play_game("One 6433")
# Out:
# Your score is One 6433!

# %%
from pydantic import BaseModel

# We create a Pydantic 'Model' by inheriting from BaseModel
class Player(BaseModel):
    name: str
    score: int
# Out:
# c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\pydantic\plugin\_schema_validator.py:40: UserWarning: ModuleNotFoundError while loading the `logfire-plugin` Pydantic plugin, this plugin will not be installed.
#
# ModuleNotFoundError("No module named 'importlib_metadata'")
#   plugins = get_plugins()

# %%
# 1. Perfect Data
player1 = Player(name="Alex", score=50)
print("Player 1:", player1)
print("----")
# Out:
# Player 1: name='Alex' score=50
# ----

# %%
player2 = Player(name="Sam", score="100")
print("Player 2:", player2)
# Out:
# Player 2: name='Sam' score=100

# %%
# 3. Bad Data
# This will crash because "Fifty" cannot be magically converted to the number 50.
player3 = Player(name="Max", score="Fifty")
# Out:
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# Cell In[5], line 3
#       1 # 3. Bad Data
#       2 # This will crash because "Fifty" cannot be magically converted to the number 50.
# ----> 3 player3 = Player(name="Max", score="Fifty")
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\pydantic\main.py:263, in BaseModel.__init__(self, **data)
#     261 # `__tracebackhide__` tells pytest and some other tools to omit this function from tracebacks
#     262 __tracebackhide__ = True
# --> 263 validated_self = self.__pydantic_validator__.validate_python(data, self_instance=self)
#     264 if self is not validated_self:
#     265     warnings.warn(
#     266         'A custom validator is returning a value other than `self`.\n'
#     267         "Returning anything other than `self` from a top level model validator isn't supported when validating via `__init__`.\n"
#     268         'See the `model_validator` docs (https://docs.pydantic.dev/latest/concepts/validators/#model-validators) for more details.',
#     269         stacklevel=2,
#     270     )
#
# ValidationError: 1 validation error for Player
# score
#   Input should be a valid integer, unable to parse string as an integer [type=int_parsing, input_value='Fifty', input_type=str]
#     For further information visit https://errors.pydantic.dev/2.13/v/int_parsing

# %%
import nest_asyncio
nest_asyncio.apply()

import os
from dotenv import load_dotenv
from pydantic_ai import Agent

# %%
# Load environment variables (Make sure GROQ_API_KEY is set in your root .env file!)
load_dotenv()
# Out:
# True

# %%
import asyncio
from pydantic_ai import Agent

basic_agent = Agent("groq:llama-3.1-8b-instant")

response = await basic_agent.run(
    "Why is the sky blue? Give reply in a funny way, in 10 words."
)

print(response.output)
# Out:
# ---------------------------------------------------------------------------
# AsyncLibraryNotFoundError                 Traceback (most recent call last)
# Cell In[10], line 6
#       2 from pydantic_ai import Agent
#       3
#       4 basic_agent = Agent("groq:llama-3.1-8b-instant")
#       5
# ----> 6 response = await basic_agent.run(
#       7     "Why is the sky blue? Give reply in a funny way, in 10 words."
#       8 )
#       9
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\pydantic_ai\agent\abstract.py:211, in AbstractAgent.run(self, user_prompt, output_type, message_history, model, deps, model_settings, usage_limits, usage, infer_name, toolsets, event_stream_handler)
#     198 event_stream_handler = event_stream_handler or self.event_stream_handler
#     200 async with self.iter(
#     201     user_prompt=user_prompt,
#     202     output_type=output_type,
#    (...)    209     toolsets=toolsets,
#     210 ) as agent_run:
# --> 211     async for node in agent_run:
#     212         if event_stream_handler is not None and (
#     213             self.is_model_request_node(node) or self.is_call_tools_node(node)
#     214         ):
#     215             async with node.stream(agent_run.ctx) as stream:
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\pydantic_ai\run.py:149, in AgentRun.__anext__(self)
#     145 async def __anext__(
#     146     self,
#     147 ) -> _agent_graph.AgentNode[AgentDepsT, OutputDataT] | End[FinalResult[OutputDataT]]:
#     148     """Advance to the next node automatically based on the last returned node."""
# --> 149     next_node = await self._graph_run.__anext__()
#     150     if _agent_graph.is_agent_node(node=next_node):
#     151         return next_node
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\pydantic_graph\graph.py:761, in GraphRun.__anext__(self)
#     758 if isinstance(self._next_node, End):
#     759     raise StopAsyncIteration
# --> 761 return await self.next(self._next_node)
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\pydantic_graph\graph.py:734, in GraphRun.next(self, node)
#     732     async with self.persistence.record_run(node_snapshot_id):
#     733         ctx = GraphRunContext(self.state, self.deps)
# --> 734         self._next_node = await node.run(ctx)
#     736 if isinstance(self._next_node, End):
#     737     self._snapshot_id = self._next_node.get_snapshot_id()
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\pydantic_ai\_agent_graph.py:297, in ModelRequestNode.run(self, ctx)
#     292 if self._did_stream:
#     293     # `self._result` gets set when exiting the `stream` contextmanager, so hitting this
#     294     # means that the stream was started but not finished before `run()` was called
#     295     raise exceptions.AgentRunError('You must finish streaming before calling run()')  # pragma: no cover
# --> 297 return await self._make_request(ctx)
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\pydantic_ai\_agent_graph.py:339, in ModelRequestNode._make_request(self, ctx)
#     336     return self._result  # pragma: no cover
#     338 model_settings, model_request_parameters, message_history, _ = await self._prepare_request(ctx)
# --> 339 model_response = await ctx.deps.model.request(message_history, model_settings, model_request_parameters)
#     340 ctx.state.usage.requests += 1
#     342 return self._finish_handling(ctx, model_response)
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\pydantic_ai\models\groq.py:172, in GroqModel.request(self, messages, model_settings, model_request_parameters)
#     165 async def request(
#     166     self,
#     167     messages: list[ModelMessage],
#     168     model_settings: ModelSettings | None,
#     169     model_request_parameters: ModelRequestParameters,
#     170 ) -> ModelResponse:
#     171     check_allow_model_requests()
# --> 172     response = await self._completions_create(
#     173         messages, False, cast(GroqModelSettings, model_settings or {}), model_request_parameters
#     174     )
#     175     model_response = self._process_response(response)
#     176     return model_response
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\pydantic_ai\models\groq.py:234, in GroqModel._completions_create(self, messages, stream, model_settings, model_request_parameters)
#     232     extra_headers = model_settings.get('extra_headers', {})
#     233     extra_headers.setdefault('User-Agent', get_user_agent())
# --> 234     return await self.client.chat.completions.create(
#     235         model=self._model_name,
#     236         messages=groq_messages,
#     237         n=1,
#     238         parallel_tool_calls=model_settings.get('parallel_tool_calls', NOT_GIVEN),
#     239         tools=tools or NOT_GIVEN,
#     240         tool_choice=tool_choice or NOT_GIVEN,
#     241         stop=model_settings.get('stop_sequences', NOT_GIVEN),
#     242         stream=stream,
#     243         max_tokens=model_settings.get('max_tokens', NOT_GIVEN),
#     244         temperature=model_settings.get('temperature', NOT_GIVEN),
#     245         top_p=model_settings.get('top_p', NOT_GIVEN),
#     246         timeout=model_settings.get('timeout', NOT_GIVEN),
#     247         seed=model_settings.get('seed', NOT_GIVEN),
#     248         presence_penalty=model_settings.get('presence_penalty', NOT_GIVEN),
#     249         reasoning_format=model_settings.get('groq_reasoning_format', NOT_GIVEN),
#     250         frequency_penalty=model_settings.get('frequency_penalty', NOT_GIVEN),
#     251         logit_bias=model_settings.get('logit_bias', NOT_GIVEN),
#     252         extra_headers=extra_headers,
#     253         extra_body=model_settings.get('extra_body'),
#     254     )
#     255 except APIStatusError as e:
#     256     if (status_code := e.status_code) >= 400:
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\groq\resources\chat\completions.py:941, in AsyncCompletions.create(self, messages, model, citation_options, compound_custom, disable_tool_validation, documents, exclude_domains, frequency_penalty, function_call, functions, include_domains, include_reasoning, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, n, parallel_tool_calls, presence_penalty, reasoning_effort, reasoning_format, response_format, search_settings, seed, service_tier, stop, store, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     721 async def create(
#     722     self,
#     723     *,
#    (...)    780     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     781 ) -> ChatCompletion | AsyncStream[ChatCompletionChunk]:
#     782     """
#     783     Creates a model response for the given chat conversation.
#     784
#    (...)    939       timeout: Override the client-level default timeout for this request, in seconds
#     940     """
# --> 941     return await self._post(
#     942         "/openai/v1/chat/completions",
#     943         body=await async_maybe_transform(
#     944             {
#     945                 "messages": messages,
#     946                 "model": model,
#     947                 "citation_options": citation_options,
#     948                 "compound_custom": compound_custom,
#     949                 "disable_tool_validation": disable_tool_validation,
#     950                 "documents": documents,
#     951                 "exclude_domains": exclude_domains,
#     952                 "frequency_penalty": frequency_penalty,
#     953                 "function_call": function_call,
#     954                 "functions": functions,
#     955                 "include_domains": include_domains,
#     956                 "include_reasoning": include_reasoning,
#     957                 "logit_bias": logit_bias,
#     958                 "logprobs": logprobs,
#     959                 "max_completion_tokens": max_completion_tokens,
#     960                 "max_tokens": max_tokens,
#     961                 "metadata": metadata,
#     962                 "n": n,
#     963                 "parallel_tool_calls": parallel_tool_calls,
#     964                 "presence_penalty": presence_penalty,
#     965                 "reasoning_effort": reasoning_effort,
#     966                 "reasoning_format": reasoning_format,
#     967                 "response_format": response_format,
#     968                 "search_settings": search_settings,
#     969                 "seed": seed,
#     970                 "service_tier": service_tier,
#     971                 "stop": stop,
#     972                 "store": store,
#     973                 "stream": stream,
#     974                 "temperature": temperature,
#     975                 "tool_choice": tool_choice,
#     976                 "tools": tools,
#     977                 "top_logprobs": top_logprobs,
#     978                 "top_p": top_p,
#     979                 "user": user,
#     980             },
#     981             completion_create_params.CompletionCreateParams,
#     982         ),
#     983         options=make_request_options(
#     984             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     985         ),
#     986         cast_to=ChatCompletion,
#     987         stream=stream or False,
#     988         stream_cls=AsyncStream[ChatCompletionChunk],
#     989     )
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\groq\_base_client.py:1856, in AsyncAPIClient.post(self, path, cast_to, body, content, files, options, stream, stream_cls)
#    1847     warnings.warn(
#    1848         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1849         "Please pass raw bytes via the `content` parameter instead.",
#    1850         DeprecationWarning,
#    1851         stacklevel=2,
#    1852     )
#    1853 opts = FinalRequestOptions.construct(
#    1854     method="post", url=path, json_data=body, content=content, files=await async_to_httpx_files(files), **options
#    1855 )
# -> 1856 return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\groq\_base_client.py:1556, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1545 async def request(
#    1546     self,
#    1547     cast_to: Type[ResponseT],
#    (...)   1551     stream_cls: type[_AsyncStreamT] | None = None,
#    1552 ) -> ResponseT | _AsyncStreamT:
#    1553     if self._platform is None:
#    1554         # `get_platform` can make blocking IO calls so we
#    1555         # execute it earlier while we are in an async context
# -> 1556         self._platform = await asyncify(get_platform)()
#    1558     cast_to = self._maybe_override_cast_to(cast_to, options)
#    1560     # create a copy of the options we were given so that if the
#    1561     # options are mutated later & we then retry, the retries are
#    1562     # given the original options
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\groq\_utils\_sync.py:56, in asyncify.<locals>.wrapper(*args, **kwargs)
#      55 async def wrapper(*args: T_ParamSpec.args, **kwargs: T_ParamSpec.kwargs) -> T_Retval:
# ---> 56     return await to_thread(function, *args, **kwargs)
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\groq\_utils\_sync.py:19, in to_thread(func, *args, **kwargs)
#      16 async def to_thread(
#      17     func: Callable[T_ParamSpec, T_Retval], /, *args: T_ParamSpec.args, **kwargs: T_ParamSpec.kwargs
#      18 ) -> T_Retval:
# ---> 19     if sniffio.current_async_library() == "asyncio":
#      20         return await asyncio.to_thread(func, *args, **kwargs)
#      22     return await anyio.to_thread.run_sync(
#      23         functools.partial(func, *args, **kwargs),
#      24     )
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\sniffio\_impl.py:93, in current_async_library()
#      90     if curio_running():
#      91         return 'curio'
# ---> 93 raise AsyncLibraryNotFoundError(
#      94     "unknown async library, or not in async context"
#      95 )
#
# AsyncLibraryNotFoundError: unknown async library, or not in async context

# %%
# !logfire auth
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Projects\ecom-pydentic\ecpyenv\Scripts\logfire.exe\__main__.py", line 2, in <module>
#     from logfire.cli import main
#   File "C:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\logfire\__init__.py", line 11, in <module>
#     from ._internal.cli import logfire_info
#   File "C:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\logfire\_internal\cli\__init__.py", line 23, in <module>
#     from ...version import VERSION
#   File "C:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\logfire\version.py", line 3, in <module>
#     import importlib_metadata
# ModuleNotFoundError: No module named 'importlib_metadata'

# %%
# !logfire projects use ecom-ai
# Out:
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "c:\Projects\ecom-pydentic\ecpyenv\Scripts\logfire.exe\__main__.py", line 2, in <module>
#     from logfire.cli import main
#   File "C:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\logfire\__init__.py", line 11, in <module>
#     from ._internal.cli import logfire_info
#   File "C:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\logfire\_internal\cli\__init__.py", line 23, in <module>
#     from ...version import VERSION
#   File "C:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\logfire\version.py", line 3, in <module>
#     import importlib_metadata
# ModuleNotFoundError: No module named 'importlib_metadata'

# %%
import logfire
logfire.configure()
logfire.instrument_pydantic_ai()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 import logfire
#       2 logfire.configure()
#       3 logfire.instrument_pydantic_ai()
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\logfire\__init__.py:11
#       9 from ._internal.auto_trace import AutoTraceModule
#      10 from ._internal.auto_trace.rewrite_ast import no_auto_trace
# ---> 11 from ._internal.cli import logfire_info
#      12 from ._internal.config import AdvancedOptions, CodeSource, ConsoleOptions, MetricsOptions, PydanticPlugin, configure
#      13 from ._internal.constants import LevelName
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\logfire\_internal\cli\__init__.py:23
#      20 from logfire.exceptions import LogfireConfigError
#      21 from logfire.propagate import ContextCarrier, get_context
# ---> 23 from ...version import VERSION
#      24 from ..auth import HOME_LOGFIRE
#      25 from ..client import LogfireClient
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\logfire\version.py:3
#       1 """Version information for logfire package."""
# ----> 3 import importlib_metadata
#       5 VERSION = importlib_metadata.version('logfire')
#
# ModuleNotFoundError: No module named 'importlib_metadata'

# %%
from pydantic_ai import Agent

pirate_agent = Agent(
    name="monkey-d-luffy",
    model="groq:llama-3.3-70b-versatile",
    system_prompt=(
        "You are Captain Monkey D Luffy. Who is on a mission to find One Piece. "
        "You must answer every question like the King of Pirates. "
        "Never drop your character."
    )
)

# %%
pirate_agent
# Out:
# Agent(model=GroqModel(), name='monkey-d-luffy', end_strategy='early', model_settings=None, output_type=<class 'str'>, instrument=None)

# %%
response = pirate_agent.run_sync("Explain how to get food on a ship. Answer in one short sentence.")

print("Pirate Agent Answer:", response.output)
# Out:
# ---------------------------------------------------------------------------
# AsyncLibraryNotFoundError                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 response = pirate_agent.run_sync("Explain how to get food on a ship. Answer in one short sentence.")
#       2
#       3 print("Pirate Agent Answer:", response.output)
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\pydantic_ai\agent\abstract.py:306, in AbstractAgent.run_sync(self, user_prompt, output_type, message_history, model, deps, model_settings, usage_limits, usage, infer_name, toolsets, event_stream_handler)
#     303 if infer_name and self.name is None:
#     304     self._infer_name(inspect.currentframe())
# --> 306 return get_event_loop().run_until_complete(
#     307     self.run(
#     308         user_prompt,
#     309         output_type=output_type,
#     310         message_history=message_history,
#     311         model=model,
#     312         deps=deps,
#     313         model_settings=model_settings,
#     314         usage_limits=usage_limits,
#     315         usage=usage,
#     316         infer_name=False,
#     317         toolsets=toolsets,
#     318         event_stream_handler=event_stream_handler,
#     319     )
#     320 )
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\nest_asyncio.py:98, in _patch_loop.<locals>.run_until_complete(self, future)
#      95 if not f.done():
#      96     raise RuntimeError(
#      97         'Event loop stopped before Future completed.')
# ---> 98 return f.result()
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\asyncio\futures.py:208, in Future.result(self)
#     206 self.__log_traceback = False
#     207 if self._exception is not None:
# --> 208     raise self._exception.with_traceback(self._exception_tb)
#     209 return self._result
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\asyncio\tasks.py:289, in Task.__step_run_and_handle_result(***failed resolving arguments***)
#     285 try:
#     286     if exc is None:
#     287         # We use the `send` method directly, because coroutines
#     288         # don't have `__iter__` and `__next__` methods.
# --> 289         result = coro.send(None)
#     290     else:
#     291         result = coro.throw(exc)
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\pydantic_ai\agent\abstract.py:211, in AbstractAgent.run(self, user_prompt, output_type, message_history, model, deps, model_settings, usage_limits, usage, infer_name, toolsets, event_stream_handler)
#     198 event_stream_handler = event_stream_handler or self.event_stream_handler
#     200 async with self.iter(
#     201     user_prompt=user_prompt,
#     202     output_type=output_type,
#    (...)    209     toolsets=toolsets,
#     210 ) as agent_run:
# --> 211     async for node in agent_run:
#     212         if event_stream_handler is not None and (
#     213             self.is_model_request_node(node) or self.is_call_tools_node(node)
#     214         ):
#     215             async with node.stream(agent_run.ctx) as stream:
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\pydantic_ai\run.py:149, in AgentRun.__anext__(self)
#     145 async def __anext__(
#     146     self,
#     147 ) -> _agent_graph.AgentNode[AgentDepsT, OutputDataT] | End[FinalResult[OutputDataT]]:
#     148     """Advance to the next node automatically based on the last returned node."""
# --> 149     next_node = await self._graph_run.__anext__()
#     150     if _agent_graph.is_agent_node(node=next_node):
#     151         return next_node
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\pydantic_graph\graph.py:761, in GraphRun.__anext__(self)
#     758 if isinstance(self._next_node, End):
#     759     raise StopAsyncIteration
# --> 761 return await self.next(self._next_node)
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\pydantic_graph\graph.py:734, in GraphRun.next(self, node)
#     732     async with self.persistence.record_run(node_snapshot_id):
#     733         ctx = GraphRunContext(self.state, self.deps)
# --> 734         self._next_node = await node.run(ctx)
#     736 if isinstance(self._next_node, End):
#     737     self._snapshot_id = self._next_node.get_snapshot_id()
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\pydantic_ai\_agent_graph.py:297, in ModelRequestNode.run(self, ctx)
#     292 if self._did_stream:
#     293     # `self._result` gets set when exiting the `stream` contextmanager, so hitting this
#     294     # means that the stream was started but not finished before `run()` was called
#     295     raise exceptions.AgentRunError('You must finish streaming before calling run()')  # pragma: no cover
# --> 297 return await self._make_request(ctx)
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\pydantic_ai\_agent_graph.py:339, in ModelRequestNode._make_request(self, ctx)
#     336     return self._result  # pragma: no cover
#     338 model_settings, model_request_parameters, message_history, _ = await self._prepare_request(ctx)
# --> 339 model_response = await ctx.deps.model.request(message_history, model_settings, model_request_parameters)
#     340 ctx.state.usage.requests += 1
#     342 return self._finish_handling(ctx, model_response)
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\pydantic_ai\models\groq.py:172, in GroqModel.request(self, messages, model_settings, model_request_parameters)
#     165 async def request(
#     166     self,
#     167     messages: list[ModelMessage],
#     168     model_settings: ModelSettings | None,
#     169     model_request_parameters: ModelRequestParameters,
#     170 ) -> ModelResponse:
#     171     check_allow_model_requests()
# --> 172     response = await self._completions_create(
#     173         messages, False, cast(GroqModelSettings, model_settings or {}), model_request_parameters
#     174     )
#     175     model_response = self._process_response(response)
#     176     return model_response
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\pydantic_ai\models\groq.py:234, in GroqModel._completions_create(self, messages, stream, model_settings, model_request_parameters)
#     232     extra_headers = model_settings.get('extra_headers', {})
#     233     extra_headers.setdefault('User-Agent', get_user_agent())
# --> 234     return await self.client.chat.completions.create(
#     235         model=self._model_name,
#     236         messages=groq_messages,
#     237         n=1,
#     238         parallel_tool_calls=model_settings.get('parallel_tool_calls', NOT_GIVEN),
#     239         tools=tools or NOT_GIVEN,
#     240         tool_choice=tool_choice or NOT_GIVEN,
#     241         stop=model_settings.get('stop_sequences', NOT_GIVEN),
#     242         stream=stream,
#     243         max_tokens=model_settings.get('max_tokens', NOT_GIVEN),
#     244         temperature=model_settings.get('temperature', NOT_GIVEN),
#     245         top_p=model_settings.get('top_p', NOT_GIVEN),
#     246         timeout=model_settings.get('timeout', NOT_GIVEN),
#     247         seed=model_settings.get('seed', NOT_GIVEN),
#     248         presence_penalty=model_settings.get('presence_penalty', NOT_GIVEN),
#     249         reasoning_format=model_settings.get('groq_reasoning_format', NOT_GIVEN),
#     250         frequency_penalty=model_settings.get('frequency_penalty', NOT_GIVEN),
#     251         logit_bias=model_settings.get('logit_bias', NOT_GIVEN),
#     252         extra_headers=extra_headers,
#     253         extra_body=model_settings.get('extra_body'),
#     254     )
#     255 except APIStatusError as e:
#     256     if (status_code := e.status_code) >= 400:
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\groq\resources\chat\completions.py:941, in AsyncCompletions.create(self, messages, model, citation_options, compound_custom, disable_tool_validation, documents, exclude_domains, frequency_penalty, function_call, functions, include_domains, include_reasoning, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, n, parallel_tool_calls, presence_penalty, reasoning_effort, reasoning_format, response_format, search_settings, seed, service_tier, stop, store, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     721 async def create(
#     722     self,
#     723     *,
#    (...)    780     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     781 ) -> ChatCompletion | AsyncStream[ChatCompletionChunk]:
#     782     """
#     783     Creates a model response for the given chat conversation.
#     784
#    (...)    939       timeout: Override the client-level default timeout for this request, in seconds
#     940     """
# --> 941     return await self._post(
#     942         "/openai/v1/chat/completions",
#     943         body=await async_maybe_transform(
#     944             {
#     945                 "messages": messages,
#     946                 "model": model,
#     947                 "citation_options": citation_options,
#     948                 "compound_custom": compound_custom,
#     949                 "disable_tool_validation": disable_tool_validation,
#     950                 "documents": documents,
#     951                 "exclude_domains": exclude_domains,
#     952                 "frequency_penalty": frequency_penalty,
#     953                 "function_call": function_call,
#     954                 "functions": functions,
#     955                 "include_domains": include_domains,
#     956                 "include_reasoning": include_reasoning,
#     957                 "logit_bias": logit_bias,
#     958                 "logprobs": logprobs,
#     959                 "max_completion_tokens": max_completion_tokens,
#     960                 "max_tokens": max_tokens,
#     961                 "metadata": metadata,
#     962                 "n": n,
#     963                 "parallel_tool_calls": parallel_tool_calls,
#     964                 "presence_penalty": presence_penalty,
#     965                 "reasoning_effort": reasoning_effort,
#     966                 "reasoning_format": reasoning_format,
#     967                 "response_format": response_format,
#     968                 "search_settings": search_settings,
#     969                 "seed": seed,
#     970                 "service_tier": service_tier,
#     971                 "stop": stop,
#     972                 "store": store,
#     973                 "stream": stream,
#     974                 "temperature": temperature,
#     975                 "tool_choice": tool_choice,
#     976                 "tools": tools,
#     977                 "top_logprobs": top_logprobs,
#     978                 "top_p": top_p,
#     979                 "user": user,
#     980             },
#     981             completion_create_params.CompletionCreateParams,
#     982         ),
#     983         options=make_request_options(
#     984             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     985         ),
#     986         cast_to=ChatCompletion,
#     987         stream=stream or False,
#     988         stream_cls=AsyncStream[ChatCompletionChunk],
#     989     )
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\groq\_base_client.py:1856, in AsyncAPIClient.post(self, path, cast_to, body, content, files, options, stream, stream_cls)
#    1847     warnings.warn(
#    1848         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1849         "Please pass raw bytes via the `content` parameter instead.",
#    1850         DeprecationWarning,
#    1851         stacklevel=2,
#    1852     )
#    1853 opts = FinalRequestOptions.construct(
#    1854     method="post", url=path, json_data=body, content=content, files=await async_to_httpx_files(files), **options
#    1855 )
# -> 1856 return await self.request(cast_to, opts, stream=stream, stream_cls=stream_cls)
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\groq\_base_client.py:1556, in AsyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1545 async def request(
#    1546     self,
#    1547     cast_to: Type[ResponseT],
#    (...)   1551     stream_cls: type[_AsyncStreamT] | None = None,
#    1552 ) -> ResponseT | _AsyncStreamT:
#    1553     if self._platform is None:
#    1554         # `get_platform` can make blocking IO calls so we
#    1555         # execute it earlier while we are in an async context
# -> 1556         self._platform = await asyncify(get_platform)()
#    1558     cast_to = self._maybe_override_cast_to(cast_to, options)
#    1560     # create a copy of the options we were given so that if the
#    1561     # options are mutated later & we then retry, the retries are
#    1562     # given the original options
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\groq\_utils\_sync.py:56, in asyncify.<locals>.wrapper(*args, **kwargs)
#      55 async def wrapper(*args: T_ParamSpec.args, **kwargs: T_ParamSpec.kwargs) -> T_Retval:
# ---> 56     return await to_thread(function, *args, **kwargs)
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\groq\_utils\_sync.py:19, in to_thread(func, *args, **kwargs)
#      16 async def to_thread(
#      17     func: Callable[T_ParamSpec, T_Retval], /, *args: T_ParamSpec.args, **kwargs: T_ParamSpec.kwargs
#      18 ) -> T_Retval:
# ---> 19     if sniffio.current_async_library() == "asyncio":
#      20         return await asyncio.to_thread(func, *args, **kwargs)
#      22     return await anyio.to_thread.run_sync(
#      23         functools.partial(func, *args, **kwargs),
#      24     )
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\sniffio\_impl.py:93, in current_async_library()
#      90     if curio_running():
#      91         return 'curio'
# ---> 93 raise AsyncLibraryNotFoundError(
#      94     "unknown async library, or not in async context"
#      95 )
#
# AsyncLibraryNotFoundError: unknown async library, or not in async context
