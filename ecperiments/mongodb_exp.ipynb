# %%
print("ok")
# Out:
# ok

# %%
from pymongo import MongoClient

client = MongoClient("mongodb+srv://deepakthakur0466_db_user:jdALWIJCCs3AXViL@ecom-pydentic.5yrvqoj.mongodb.net/?appName=ecom-pydentic")

db = client["ecom_db"]

collection = db["orders"]
print("connected t mongobd")
# Out:
# connected t mongobd

# %%
product = {
    "name": "Men Casual",
    "price": 999,
    "category": "men"
}

collection.insert_one(product)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[6], line 7
#       3     "price": 999,
#       4     "category": "men"
#       5 }
#       6
# ----> 7 collection.insert_one(product)
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\pymongo\synchronous\collection.py:890, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     886     document["_id"] = ObjectId()  # type: ignore[index]
#     888 write_concern = self._write_concern_for(session)
#     889 return InsertOneResult(
# --> 890     self._insert_one(
#     891         document,
#     892         ordered=True,
#     893         write_concern=write_concern,
#     894         op_id=None,
#     895         bypass_doc_val=bypass_document_validation,
#     896         session=session,
#     897         comment=comment,
#     898     ),
# ...

# %%
print(collection.find_one("Men Casual Shirt"))
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(collection.find_one("Men Casual Shirt"))
#       2
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\pymongo\synchronous\collection.py:1754, in Collection.find_one(self, filter, *args, **kwargs)
#    1752     filter = {"_id": filter}
#    1753 cursor = self.find(filter, *args, **kwargs)
# -> 1754 for result in cursor.limit(-1):
#    1755     return result
#    1756 return None
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\pymongo\synchronous\cursor.py:1166, in Cursor.__next__(self)
#    1165 def __next__(self) -> _DocumentType:
# -> 1166     return self.next()
#
# File c:\Projects\ecom-pydentic\ecpyenv\Lib\site-packages\pymongo\synchronous\cursor.py:1142, in Cursor.next(self)
#    1140 if self._empty:
#    1141     raise StopIteration
# ...
